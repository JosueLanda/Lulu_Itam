# %% [markdown]
# # Automatizacion

# %% [markdown]
# # Compilacion

# %%
cd
# Out:
# /home/jovyan

# %%
import subprocess
from subprocess import Popen, PIPE

subprocess.run(["gcc", "./sistema_ecuaciones.c", "-lm","-o", "executable"])
# Out:
# CompletedProcess(args=['gcc', './sistema_ecuaciones.c', '-lm', '-o', 'executable'], returncode=0)

# %%
for i in range(2,10):
    for j in range(3,10):
        for k in range(4,10):
            #print(i,j,k,-i,-i,j,k,i,-j,k,i,j)

            exe = ("./executable")
            with Popen(exe, shell=True, stdin=PIPE,stdout=PIPE) as proc:
                
                output, _ = proc.communicate(bytes(f'{j} {i} {k} {-i} {-i} {j} {k} {i} {j} {k} {i} {j} \n',encoding='utf-8'))
                
                if str(output).find('inf')==-1:
                    print(f'{j} {i} {k} {-i} {-i} {j} {k} {i} {j} {k} {i} {j}')
                    print(str(output).replace("b","").replace("'",""))
                    print("\n")
            
        if j == 3:
            break
# Out:
# 3 2 4 -2 -2 3 4 2 3 4 2 3
# 7.00\n-8.50\n
#
#
# 3 2 5 -2 -2 3 5 2 3 5 2 3
# 8.00\n-9.50\n
#
#
# 3 2 6 -2 -2 3 6 2 3 6 2 3
# 9.00\n-10.50\n
#
#
# 3 2 7 -2 -2 3 7 2 3 7 2 3
# 10.00\n-11.50\n
#
#
# 3 2 8 -2 -2 3 8 2 3 8 2 3
# 11.00\n-12.50\n
#
#
# 3 2 9 -2 -2 3 9 2 3 9 2 3
# 12.00\n-13.50\n
#
#
# 3 3 4 -3 -3 3 4 3 3 4 3 3
# No existe solucion unica\n
#
#
# 3 3 5 -3 -3 3 5 3 3 5 3 3
# No existe solucion unica\n
#
#
# 3 3 6 -3 -3 3 6 3 3 6 3 3
# No existe solucion unica\n
#
#
# 3 3 7 -3 -3 3 7 3 3 7 3 3
# No existe solucion unica\n
#
#
# 3 3 8 -3 -3 3 8 3 3 8 3 3
# No existe solucion unica\n
#
#
# 3 3 9 -3 -3 3 9 3 3 9 3 3
# No existe solucion unica\n
#
#
# 3 4 4 -4 -4 3 4 4 3 4 4 3
# -7.00\n6.25\n
#
#
# 3 4 5 -4 -4 3 5 4 3 5 4 3
# -8.00\n7.25\n
#
#
# 3 4 6 -4 -4 3 6 4 3 6 4 3
# -9.00\n8.25\n
#
#
# 3 4 7 -4 -4 3 7 4 3 7 4 3
# -10.00\n9.25\n
#
#
# 3 4 8 -4 -4 3 8 4 3 8 4 3
# -11.00\n10.25\n
#
#
# 3 4 9 -4 -4 3 9 4 3 9 4 3
# -12.00\n11.25\n
#
#
# 3 5 4 -5 -5 3 4 5 3 4 5 3
# -3.50\n2.90\n
#
#
# 3 5 5 -5 -5 3 5 5 3 5 5 3
# -4.00\n3.40\n
#
#
# 3 5 6 -5 -5 3 6 5 3 6 5 3
# -4.50\n3.90\n
#
#
# 3 5 7 -5 -5 3 7 5 3 7 5 3
# -5.00\n4.40\n
#
#
# 3 5 8 -5 -5 3 8 5 3 8 5 3
# -5.50\n4.90\n
#
#
# 3 5 9 -5 -5 3 9 5 3 9 5 3
# -6.00\n5.40\n
#
#
# 3 6 4 -6 -6 3 4 6 3 4 6 3
# -2.33\n1.83\n
#
#
# 3 6 5 -6 -6 3 5 6 3 5 6 3
# -2.67\n2.17\n
#
#
# 3 6 6 -6 -6 3 6 6 3 6 6 3
# -3.00\n2.50\n
#
#
# 3 6 7 -6 -6 3 7 6 3 7 6 3
# -3.33\n2.83\n
#
#
# 3 6 8 -6 -6 3 8 6 3 8 6 3
# -3.67\n3.17\n
#
#
# 3 6 9 -6 -6 3 9 6 3 9 6 3
# -4.00\n3.50\n
#
#
# 3 7 4 -7 -7 3 4 7 3 4 7 3
# -1.75\n1.32\n
#
#
# 3 7 5 -7 -7 3 5 7 3 5 7 3
# -2.00\n1.57\n
#
#
# 3 7 6 -7 -7 3 6 7 3 6 7 3
# -2.25\n1.82\n
#
#
# 3 7 7 -7 -7 3 7 7 3 7 7 3
# -2.50\n2.07\n
#
#
# 3 7 8 -7 -7 3 8 7 3 8 7 3
# -2.75\n2.32\n
#
#
# 3 7 9 -7 -7 3 9 7 3 9 7 3
# -3.00\n2.57\n
#
#
# 3 8 4 -8 -8 3 4 8 3 4 8 3
# -1.40\n1.02\n
#
#
# 3 8 5 -8 -8 3 5 8 3 5 8 3
# -1.60\n1.23\n
#
#
# 3 8 6 -8 -8 3 6 8 3 6 8 3
# -1.80\n1.42\n
#
#
# 3 8 7 -8 -8 3 7 8 3 7 8 3
# -2.00\n1.62\n
#
#
# 3 8 8 -8 -8 3 8 8 3 8 8 3
# -2.20\n1.83\n
#
#
# 3 8 9 -8 -8 3 9 8 3 9 8 3
# -2.40\n2.03\n
#
#
# 3 9 4 -9 -9 3 4 9 3 4 9 3
# -1.17\n0.83\n
#
#
# 3 9 5 -9 -9 3 5 9 3 5 9 3
# -1.33\n1.00\n
#
#
# 3 9 6 -9 -9 3 6 9 3 6 9 3
# -1.50\n1.17\n
#
#
# 3 9 7 -9 -9 3 7 9 3 7 9 3
# -1.67\n1.33\n
#
#
# 3 9 8 -9 -9 3 8 9 3 8 9 3
# -1.83\n1.50\n
#
#
# 3 9 9 -9 -9 3 9 9 3 9 9 3
# -2.00\n1.67\n
